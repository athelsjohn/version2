# %%
import numpy as np
import pandas as pd
from datetime import datetime
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering, SpectralClustering, OPTICS
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import PowerTransformer, RobustScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/home/athel/Desktop/Litmus7/order/MergedData.csv')
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(['Customer ID', 'Date'])
df['Order Gap'] = df.groupby('Customer ID')['Date'].diff().dt.days
df['Order Gap'] = df['Order Gap'].fillna(0)
df.head()
# Out:
#        Order ID Customer ID Warehouse ID  Customer Age Customer Gender  \
# 10609      4248     CUST001        WH003            24          Female
# 10610      4248     CUST001        WH003            24          Female
# 10611      4248     CUST001        WH003            24          Female
# 10612      4248     CUST001        WH003            24          Female
# 10613      4248     CUST001        WH003            24          Female
#
#             Date   Product ID   SKU ID                Category  Quantity  \
# 10609 2023-03-17  Product_187  SKU_484         Home Appliances         2
# 10610 2023-03-17  Product_056  SKU_689             Electronics         2
# 10611 2023-03-17  Product_009  SKU_234         Home Appliances         5
# 10612 2023-03-17  Product_126  SKU_651  Beauty & Personal Care         3
# 10613 2023-03-17  Product_040  SKU_534       Health & Wellness         1
#
#        Price per Unit  Order Gap
# 10609          786.10        0.0
# 10610          864.04        0.0
# 10611          604.22        0.0
# 10612           28.26        0.0
# 10613          203.58        0.0

# %%
df['Sales'] = df['Quantity'] * df['Price per Unit']

# %%
today = pd.to_datetime(datetime.now().date())
df['Recency'] = (today - df['Date']).dt.days

# %%
customer_df = df.groupby('Customer ID').agg(
    total_spend = ('Sales', 'sum'),
    purchase_frequency = ('Order ID', 'nunique'),
    avg_basket_size = ('Quantity', 'mean'),
    cat_diversity = ('Category','nunique'),
    recency = ('Date', lambda x: (pd.Timestamp.today() - x.max()).days),
    gap = ('Order Gap', lambda x: x.sum() / (np.count_nonzero(x) + 1) if np.count_nonzero(x) >= 0 else None),
    age = ('Customer Age', 'first')
).reset_index()

print(df[df['Customer ID'] == 'CUST001']['Order Gap'])
customer_df
# Out:
# 10609     0.0
# 10610     0.0
# 10611     0.0
# 10612     0.0
# 10613     0.0
# 6239     20.0
# 6240      0.0
# 6241      0.0
# 6242      0.0
# 6243      0.0
# 6244      0.0
# 6245      0.0
# 6246      0.0
# 21930    30.0
# 13796     5.0
# 13797     0.0
# 13798     0.0
# 15947     2.0
# 15948     0.0
# 15949     0.0
# 15950     0.0
# 15951     0.0
# 15952     0.0
# 15953     0.0
# 15954     0.0
# 15955     0.0
# 15956     0.0
# 15957     0.0
# 15958     0.0
# 10124    36.0
# 10125     0.0
# 10126     0.0
# 10127     0.0
# 10128     0.0
# 550      75.0
# 551       0.0
# 552       0.0
# 6362     44.0
# 6363      0.0
# 6364      0.0
# 6365      0.0
# 6366      0.0
# 6367      0.0
# Name: Order Gap, dtype: float64
#     Customer ID  total_spend  purchase_frequency  avg_basket_size  \
# 0       CUST001     58005.44                   8         3.162791
# 1       CUST002     39259.36                  10         3.344828
# 2       CUST003     33258.79                   8         2.964286
# 3       CUST004     16586.12                   3         2.583333
# 4       CUST005     41222.16                   5         3.148148
# ..          ...          ...                 ...              ...
# 995     CUST995     19477.26                   4         3.000000
# 996     CUST996      7798.51                   2         3.000000
# 997     CUST997     69985.87                   9         3.021739
# 998     CUST998     36406.23                   7         2.793103
# 999     CUST999     47596.83                   9         2.878788
#
#      cat_diversity  recency        gap  age
# 0               10      590  26.500000   24
# 1                9      563  26.500000   35
# 2                9      565  28.000000   26
# 3                5      556  95.000000   25
# 4                9      625  47.800000   29
# ..             ...      ...        ...  ...
# 995              7      589  62.750000   60
# 996              4      627  96.000000   52
# 997             10      583  30.333333   46
# 998             10      572  40.428571   47
# 999              9      513  35.111111   37
#
# [1000 rows x 8 columns]

# %%
features = ['total_spend','purchase_frequency','avg_basket_size','cat_diversity','age','recency','gap']
X = customer_df[features].values
X
# Out:
# array([[5.80054400e+04, 8.00000000e+00, 3.16279070e+00, ...,
#         2.40000000e+01, 5.90000000e+02, 2.65000000e+01],
#        [3.92593600e+04, 1.00000000e+01, 3.34482759e+00, ...,
#         3.50000000e+01, 5.63000000e+02, 2.65000000e+01],
#        [3.32587900e+04, 8.00000000e+00, 2.96428571e+00, ...,
#         2.60000000e+01, 5.65000000e+02, 2.80000000e+01],
#        ...,
#        [6.99858700e+04, 9.00000000e+00, 3.02173913e+00, ...,
#         4.60000000e+01, 5.83000000e+02, 3.03333333e+01],
#        [3.64062300e+04, 7.00000000e+00, 2.79310345e+00, ...,
#         4.70000000e+01, 5.72000000e+02, 4.04285714e+01],
#        [4.75968300e+04, 9.00000000e+00, 2.87878788e+00, ...,
#         3.70000000e+01, 5.13000000e+02, 3.51111111e+01]])

# %%
pt = PowerTransformer(method='yeo-johnson', standardize=True)
pca = PCA(n_components=2)
# Fit and transform in sequence
X_pt = pt.fit_transform(X)
X_pca = pca.fit_transform(X_pt)

# %%
plt.figure(figsize = (15,6))

plt.subplot(1,3,1)
sns.boxplot(x = customer_df['total_spend'])
plt.title('Spend Boxplot')
plt.xlabel('Total Spend')

plt.subplot(1,3,2)
plt.boxplot(x = customer_df['purchase_frequency'])
plt.title('Frequency Boxplot')
plt.xlabel('Frequency')


plt.subplot(1,3,3)
plt.boxplot(x = customer_df['recency'])
plt.title ('Recency Boxplot')
plt.xlabel('Recency')

plt.tight_layout()
plt.show()

customer_df.nsmallest(1, 'recency')
# Out:
#     Customer ID  total_spend  purchase_frequency  avg_basket_size  \
# 172     CUST172     44308.03                   7         3.235294
#
#      cat_diversity  recency        gap  age
# 172             10      513  47.857143   39

# %% [markdown]
# # KMeans

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
customer_df['KMeans Cluster'] = kmeans.fit_predict(X_pca)

# Plot
plt.figure(figsize=(10,6))
sns.scatterplot(x=X_pca[:,0], y=X_pca[:,1], hue=customer_df['KMeans Cluster'], palette='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('KMeans')
plt.show()

# %%
loadings = pca.components_

feature_names = ['total_spend', 'purchase_frequency', 'avg_basket_size','cat_diversity','age','recency','']
loadings_df = pd.DataFrame(loadings.T, columns = ['PC1', 'PC2'], index = feature_names)

print(loadings_df)
print(pca.explained_variance_ratio_)
# Out:
#                              PC1           PC2
# total_spend         5.701638e-01  1.477284e-01
# purchase_frequency  5.593518e-01 -6.896991e-02
# avg_basket_size     6.037347e-02  9.056041e-01
# cat_diversity       5.218559e-01  2.114970e-02
# age                 4.193662e-02 -1.468440e-01
# recency            -1.420882e-16 -8.096984e-17
#                    -2.903472e-01  3.623398e-01
# [0.44009671 0.17433946]

# %% [markdown]
# PC1 holds more weightage from total_spend, purchase_frequency and cat_diversity, while PC2 holds more weightage from avg_basket_size predominantly. Recency, however, has very negligible relevance according to this model.

# %% [markdown]
# # DBScan

# %%
dbscan = DBSCAN(eps = 0.3, min_samples = 5)
customer_df['DBScan Cluster'] = dbscan.fit_predict(X_pca)

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = X_pca[:,0], y = X_pca[:,1], hue = customer_df['DBScan Cluster'], palette = 'Set1', legend = 'full')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('DBScan')
plt.show()

# %% [markdown]
# # Hierarchical Clustering

# %%
hierarchical = AgglomerativeClustering(n_clusters = 3)
customer_df['Hierarchical Cluster'] = hierarchical.fit_predict(X_pca)

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = X_pca[:,0], y = X_pca[:,1], hue = customer_df['Hierarchical Cluster'], palette = 'Set1', legend = 'full')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('Hierarchical')
plt.show()

# %% [markdown]
# # Gaussian Mixture

# %%
gmm = GaussianMixture(n_components = 3, random_state = 42)
customer_df['GMM Cluster'] = gmm.fit_predict(X_pca)

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = X_pca[:,0], y = X_pca[:,1], hue = customer_df['GMM Cluster'], palette = 'Set1', legend = 'full')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('Gaussian')
plt.show()

# %%
spectral = SpectralClustering(n_clusters = 3, random_state = 42)
customer_df['Spectral Cluster'] = spectral.fit_predict(X_pca)

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = X_pca[:,0], y = X_pca[:,1], hue = customer_df['Spectral Cluster'], palette = 'Set1', legend = 'full')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('Gaussian')
plt.show()

# %%
score2 = silhouette_score(X_pca, kmeans.labels_)
print(f'Silhouette Score: {score2:.3f}')
# Out:
# Silhouette Score: 0.340

# %%
score3 = silhouette_score(X_pca, dbscan.labels_)
print(f'Silhouette Score: {score3:.3f}')
# Out:
# Silhouette Score: 0.371

# %%
score4 = silhouette_score(X_pca, hierarchical.labels_)
print(f'Silhouette Score: {score4:.3f}')
# Out:
# Silhouette Score: 0.399

# %%
score5 = silhouette_score(X_pca, spectral.labels_)
print(f'Silhouette Score: {score4:.3f}')
# Out:
# Silhouette Score: 0.399

# %% [markdown]
# # Serialization

# %%
import pickle

# %%
with open('kmeans_model.pkl','wb') as f:
    pickle.dump(kmeans, f)

# %%
with open('pt.pkl','wb') as f:
    pickle.dump(pt, f)

# %%
with open('pca.pkl','wb') as f:
    pickle.dump(pca, f)

# %%
customer_df
# Out:
#     Customer ID  total_spend  purchase_frequency  avg_basket_size  \
# 0       CUST001     58005.44                   8         3.162791
# 1       CUST002     39259.36                  10         3.344828
# 2       CUST003     33258.79                   8         2.964286
# 3       CUST004     16586.12                   3         2.583333
# 4       CUST005     41222.16                   5         3.148148
# ..          ...          ...                 ...              ...
# 995     CUST995     19477.26                   4         3.000000
# 996     CUST996      7798.51                   2         3.000000
# 997     CUST997     69985.87                   9         3.021739
# 998     CUST998     36406.23                   7         2.793103
# 999     CUST999     47596.83                   9         2.878788
#
#      cat_diversity  recency        gap  age  KMeans Cluster  DBScan Cluster  \
# 0               10      590  26.500000   24               1               0
# 1                9      563  26.500000   35               1               0
# 2                9      565  28.000000   26               1               0
# 3                5      556  95.000000   25               2               0
# 4                9      625  47.800000   29               0               0
# ..             ...      ...        ...  ...             ...             ...
# 995              7      589  62.750000   60               2               0
# 996              4      627  96.000000   52               2               1
# 997             10      583  30.333333   46               1               0
# 998             10      572  40.428571   47               1               0
# 999              9      513  35.111111   37               1               0
#
#      Hierarchical Cluster  GMM Cluster  Spectral Cluster
# 0                       0            1                 0
# 1                       0            1                 0
# 2                       0            1                 0
# 3                       1            2                 0
# 4                       0            0                 0
# ..                    ...          ...               ...
# 995                     1            2                 0
# 996                     1            2                 0
# 997                     0            1                 0
# 998                     0            1                 0
# 999                     0            1                 0
#
# [1000 rows x 13 columns]

# %%
customer_df.iloc[998].values
# Out:
# array(['CUST998', 36406.229999999996, 7, 2.793103448275862, 10, 572,
#        40.42857142857143, 47, 1, 0, 0, 1, 0], dtype=object)
